# %% [markdown]
# #### M4W Series
#
# * [Table of Contents](M4WTOC.ipynb)
# * <a href="https://colab.research.google.com/github/4dsolutions/m4w/blob/main/Curated_Videos.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
# * [![nbviewer](https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.svg)](https://nbviewer.org/github/4dsolutions/m4w/blob/main/Curated_Videos.ipynb)

# %% [markdown]
# # Curated Videos
#
# * [math4wisdom channel](https://www.youtube.com/@math4wisdom)
# * [Kirby Urner's channel](https://www.youtube.com/@kirbyurner)

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo("zQDvjZUp4B8")

# %% [markdown]
# A first video of 2024 talking about the channel and specifically M4W.

# %%
YouTubeVideo("FVuxHadJqDc")  # https://youtu.be/FVuxHadJqDc?si=-NH1EksIeglaTebI

# %% [markdown]
# This video, from Kirby Urner's channel, gives a sense of the value added, in terms of topics tackled, in Silicon Forest maths.

# %%
YouTubeVideo("oNfbWad_4YU")

# %% [markdown]
# The simple math expressions and Markov blankets are pretty

# %%
YouTubeVideo("oDyviiN4NVo")

# %% [markdown]
# Grant is one of the foremost YouTube personalities in the math teaching space. In this interview, he talks about his process for making his animated math videos. Grant's channel is [3Blue1Brown](https://www.youtube.com/c/3blue1brown).

# %%
YouTubeVideo("byNaO_zn2fI")  # https://youtu.be/byNaO_zn2fI?si=hF6CeArv3eMZ4iIh

# %% [markdown]
# The process of learning mathematics usually involves a lot of self study, however self study turns out to be a group activity once you factor in that self study involves merging one's mind with many others. Finding guides is another part of that.

# %%
YouTubeVideo("HvMSRWTE2mI")

# %% [markdown]
# This relatively recent discovery in Number Theory regarding primes and Pascal's Triangle does not provide a practical way to test for primehood, once the primes get big enough. [Numberphile](https://www.youtube.com/c/numberphile) introduces a wide range of topics.

# %%
YouTubeVideo("BCQHnlnPusY")

# %% [markdown]
# [Daniel Shiffmann](https://en.wikipedia.org/wiki/Daniel_Shiffman) is another prolific and top-ranking YouTube teacher. His channel, [The Coding Train](https://www.youtube.com/@TheCodingTrain/about), is cram-packed with interesting videos and playlists. In our curriculum, Git and Github skills are considered core.

# %%
YouTubeVideo("K1kk8BFCbek")

# %% [markdown]
# $\phi$ plays a big role in the geometry we're doing, with the phi-scaled E modules and so on. When we scale all the edges of a tetrahedron (or any volume) by $\phi$, the volume expands by a scale factor of $\phi^{3}$.

# %%
YouTubeVideo("B1J6Ou4q8vE")

# %% [markdown]
# "I like how the protagonist's growing exposure to maths endows her with
# increasing degrees of freedom in terms of powers. Familiarity with the
# generalized principles = better able to hold one's own."
#
# [From math4wisdom](https://www.freelists.org/post/math4wisdom/Order-Chaos-Everything-and-Our-Social-Hub,8)

# %% [markdown]
# Looking for more curated videos?
#
# Here's [another gallery](https://github.com/4dsolutions/elite_school/blob/master/YoutubeGallery.ipynb) in a neighboring Github repo, with some overlap.
