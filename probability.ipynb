# %% [markdown]
# #### M4W Series
#
# * [Table of Contents](M4WTOC.ipynb)
# * <a href="https://colab.research.google.com/github/4dsolutions/m4w/blob/main/probability.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
# * [![nbviewer](https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.svg)](https://nbviewer.org/github/4dsolutions/m4w/blob/main/probability.ipynb)

# %% [markdown]
# # Probability

# %% [markdown]
# The word "probability" occurs in a "word cloud" of related concepts, such as uncertainty, likelihood, random, determined, sample space, population, average, center of gravity, mass, density, along with proper names, such as Laplace, Gauss, Bayes and Cardano.
#
# Weaving throughout is the mathematics, the musical notation of STEM. Figuring out the odds when gambling, vs-a-vs various games of chance, got the ball rolling.
#
# Probability will be described with "probability density functions" (PDFs) which, when integrated (the opposite of differentiated), become the "cumulative distrubution functions" (CDFs).

# %% [markdown]
# The most well known PDF is the Bell Curve, which owes its mathematical expression to Carl Freidrich Gauss. Ergo may we call it a Gaussian. We also call it a Normal Distribution.
# $$
#   X \sim \mathcal{N}(\mu,\,\sigma^{2})
# $$
# A Bell Curve may be characterized by two values: mean and variance. Variance describes the width of the bell, whereas the mean is where it peaks.
#
# $$
# f(x) = \frac{1}{\sigma \sqrt{2\pi} } e^{-\frac{1}{2}\left(\frac{x-\mu}{\sigma}\right)^2}
# $$

# %%
import pandas as pd
import numpy as np
from numpy import sqrt, pi, exp
from matplotlib import pyplot as plt

# %%
x = np.arange(-9, 9.1, 0.1)

# %%
sigma = 3 # np.std(x)
mu = 0    # np.mean(x)

# %%
def f(x):
    return  (1/sigma*sqrt(2*pi)) * exp( (-1/2)*( (x - mu)/sigma )**2)

# %%
F = np.vectorize(f)

# %%
plotme = pd.DataFrame({"x": x, "y": F(x)})
plotme
# Out:
#        x         y
# 0   -9.0  0.009282
# 1   -8.9  0.010253
# 2   -8.8  0.011312
# 3   -8.7  0.012467
# 4   -8.6  0.013725
# ..   ...       ...
# 176  8.6  0.013725
# 177  8.7  0.012467
# 178  8.8  0.011312
# 179  8.9  0.010253
# 180  9.0  0.009282
#
# [181 rows x 2 columns]

# %%
ax = plotme.plot(x='x', y='y', xlim=(-10, 10), ylim=(0, 1), grid=True)
plt.figtext(0.1, -0.05, "Fig 1: The Bell Curve")
plt.title("Normal Distribution")
ax.axvline(x = -2.5, color = 'black', linestyle=':')
ax.axvline(x =  2.5, color = 'black', linestyle=':');

# %% [markdown]
# The probability the some random variable x falls between -2.5 and 2.5 is the area bounded by the dotted lines and the curve between them.

# %% [markdown]
# ## The Namespace
#
# The use of "weight" and "center of gravity" ties the relative frequency of events to their relative weight, meaning likelihood. A higher frequency entails a greater "density" of events.
#
# We use "weights" in the namespace of machine learning as well, with backpropagation continually fine tuning how much credence to give each perceptron in a neural network, during the process of gradient descent.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("qIEfJ6OBGj8")

# %% [markdown]
# Getting the center of gravity means means finding a weighted average, and therefore having an expectation as to what might happen next; it's about finding (and perhaps following) a "groove" or "gradient".
#
# Probability theory is about being right to the extent current information permits i.e. is about predicting the future based on the past.
#
# Harvesting current information may be a very non-trivial endeavor and is likewise known as intelligence gathering.
#
# One might relate this endeavor of anticipating events to finding or matching patterns: "When this happens, then that happens, unless this other thing happens". Intuition plays a role.
#
# The image of "forks in the road" or "branches" arises, as expectations change going forward, based on choices made.
#
# Risk relates to variance or volatility. As the volatility of a variable increases, our risk of being wrong about its value increases. Volatility and uncertainty go hand in hand, as the VU in [VUCA](https://en.wikipedia.org/wiki/VUCA).

# %%
YouTubeVideo("wH90SbeHFhM")
